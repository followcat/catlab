# %% [markdown]
# # Gensim Lsi model testing
#
# ## Index mean
#
#     - 0: topics=100, power_iters=8, extra_samples=400
#     - 1: topics=100, power_iters=4, extra_samples=200
#     - 2: topics=100, power_iters=2, extra_samples=100(default)
#     - 3: topics=200, power_iters=2, extra_samples=100
#     - 4: topics=100, power_iters=4, extra_samples=100
#     - 5: topics=100, power_iters=2, extra_samples=200

# %% [markdown]
# ## Rank distribution

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns

sns.set()

d = np.array([
[149, 178, 54,  187, 119, 417],
[147, 220, 58,  374, 169, 88],
[150, 407, 25,  205, 203, 229],
[147, 245, 145, 260, 178, 180],
[149, 295, 344, 553, 307, 119],
[151, 333, 271, 632, 116, 229],
[150, 244, 334, 231, 256, 333],
[154, 215, 251, 547, 182, 387],
[146, 173, 116, 305, 137, 177],
[151, 216, 303, 461, 30, 306]
])

pal = sns.cubehelix_palette(len(d[0]), rot=-.5, dark=.3)
sns.violinplot(data=d, palette=pal, inner="points")

# %% [markdown]
# ## Matching distribution

# %%
import numpy as np
import seaborn as sns

sns.set()

d = np.array([
[0.27925977, 0.15936486, 0.33258274, 0.16046272, 0.29466707, 0.18339993],
[0.27985555, 0.14943007, 0.31876782, 0.11255261, 0.27017117, 0.30312881],
[0.27909958, 0.10437658, 0.36011043, 0.15205775, 0.25348023, 0.24988936],
[0.28058425, 0.14308375, 0.28908661, 0.14379117, 0.26433513, 0.26522091],
[0.27914914, 0.12455636, 0.19757105, 0.08159998, 0.21973087, 0.2929112],
[0.27919042, 0.11877851, 0.228236,   0.06513057, 0.29372069, 0.24324438],
[0.27932477, 0.14263509, 0.22048673, 0.14363879, 0.2335867,  0.2162043],
[0.27827579, 0.15001833, 0.22734798, 0.08485762, 0.25646466, 0.19437677],
[0.28029102, 0.16317195, 0.28280354, 0.13332285, 0.28860736, 0.25955614],
[0.27877343, 0.15045053, 0.2194903,  0.10263203, 0.36210033, 0.21782033]
])

pal = sns.cubehelix_palette(len(d[0]), rot=-.5, dark=.3)
sns.violinplot(data=d, palette=pal, inner="points")

# %%
import seaborn as sns
sns.set()

ranking = [
[149, 178, 54,  187, 119, 417],
[147, 220, 58,  374, 169, 88],
[150, 407, 25,  205, 203, 229],
[147, 245, 145, 260, 178, 180],
[149, 295, 344, 553, 307, 119],
[151, 333, 271, 632, 116, 229],
[150, 244, 334, 231, 256, 333],
[154, 215, 251, 547, 182, 387],
[146, 173, 116, 305, 137, 177],
[151, 216, 303, 461, 30, 306]
]

sns.heatmap(ranking, annot=True, fmt="d", linewidths=.5)

# %%
import seaborn as sns
sns.set()

score = [
[0.27925977, 0.15936486, 0.33258274, 0.16046272, 0.29466707, 0.18339993],
[0.27985555, 0.14943007, 0.31876782, 0.11255261, 0.27017117, 0.30312881],
[0.27909958, 0.10437658, 0.36011043, 0.15205775, 0.25348023, 0.24988936],
[0.28058425, 0.14308375, 0.28908661, 0.14379117, 0.26433513, 0.26522091],
[0.27914914, 0.12455636, 0.19757105, 0.08159998, 0.21973087, 0.2929112],
[0.27919042, 0.11877851, 0.228236,   0.06513057, 0.29372069, 0.24324438],
[0.27932477, 0.14263509, 0.22048673, 0.14363879, 0.2335867,  0.2162043],
[0.27827579, 0.15001833, 0.22734798, 0.08485762, 0.25646466, 0.19437677],
[0.28029102, 0.16317195, 0.28280354, 0.13332285, 0.28860736, 0.25955614],
[0.27877343, 0.15045053, 0.2194903,  0.10263203, 0.36210033, 0.21782033]
]

sns.heatmap(score, annot=True, fmt="f", linewidths=.5)

# %% [markdown]
# ## Use time

# %%
import numpy as np
import seaborn as sns
sns.set(style="darkgrid", palette="Set2")

sines = [
[267.651429892, 128.547306061, 55.2710089684, 74.1789438725, 64.5978090763, 70.6324360371],
[325.837762833, 133.783487797, 56.5689811707, 74.1053099632, 63.9891400337, 70.7415750027],
[353.336779118, 133.80072093 , 53.1370151043, 75.5115020275, 65.9133410454, 72.0779669285],
[272.736422062, 133.204905987, 51.1108100414, 72.8536241055, 65.7844481468, 70.7353999615],
[269.614863873, 135.866211891, 57.2844030857, 73.8291220665, 64.729845047 , 71.5153958797],
[268.826323986, 129.433111906, 56.2122020721, 73.1853761673, 64.6169099808, 71.2535409927],
[236.457563162, 127.920512915, 57.1998829842, 71.9699418545, 64.9254970551, 72.2390868664],
[215.745023012, 128.373788834, 57.4310519695, 74.1716279984, 65.3197290897, 72.3341069221],
[158.155761003, 130.7847929  , 57.6210391521, 74.553828001 , 64.7383041382, 76.8275361061],
[156.482337952, 138.872401953, 61.2945721149, 72.4436171055, 63.348400116 , 75.485325098 ]
]
sns.tsplot(sines, err_style="boot_traces", n_boot=500)
