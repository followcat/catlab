# %% [markdown]
# # Android Webview Research
#
# ## Webview core different
#
# |                   |Webkit for Webview	|Chromium for Webview|	备注|
# |-------------------|:------------------:|
# |HTML5|    278|    434|http://html5test.com/
# |Remote Debug|  不支持|  支持|	Android 4.4及以上支持
# |Memory Used|  小|	   大|	相差20-30M左右
# |WebAudio| 不支持|	支持|	Android 5.0及以上支持
# |WebGL	|  不支持|	支持|	Android 5.0及以上支持
# |WebRTC	|  不支持|	支持|	Android 5.0及以上支持

# %% [markdown]
# ## Android Webview 4.1~4.3

# %%
# %matplotlib inline
import android_apps_dev

android_apps_dev.webview41()

# %% [markdown]
# ## Android Webview 4.4+

# %%
import android_apps_dev

android_apps_dev.webview44()

# %%
from IPython.display import Image
Image(filename='android44chromium.png')

# %% [markdown]
# ## Apps and Browser

# %%
import android_apps_dev

android_apps_dev.apps_and_browser()

# %% [markdown]
# ## Dev steps

# %%
import android_apps_dev

android_apps_dev.pc_website()

# %%
import android_apps_dev

android_apps_dev.pcdebug_mobilewebsite()

# %%
import android_apps_dev

android_apps_dev.hand_mobiledebug_mobileapp()

# %%
import android_apps_dev

android_apps_dev.automaticdebug_mobileapp()

# %%
from wand.image import Image as WImage
img = WImage(filename='mindmap.pdf')
img
# Out:
# <wand.image.Image: 9d878d0 'PNG' (573x452)>
